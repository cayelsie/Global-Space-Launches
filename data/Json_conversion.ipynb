# %%
# Dependencies and Setup
import pandas as pd
import json

# %%
# Variable for data file
launches = "Global_Space_Launches_seperate_columns_final2.csv"


# Read the data as csv
launch_data = pd.read_csv(launches)


#Create dfs for both data files
launch_data_df = pd.DataFrame(launch_data)
launch_data_df.head()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa0 in position 0: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-20-794549797a9c> in <module>
#       4
#       5 # Read the data as csv
# ----> 6 launch_data = pd.read_csv(launches)
#       7
#       8
#
# ...

# %%
global_launches = launch_data_df.to_json(r'global_space_launches.json', orient= "records", indent=2 )
print(global_launches)
# Out:
# None

# %%
# Out:
# {
#   "0":{
#     "Company Name":"AEB",
#     "Location":"VLS Pad, Alc?\u203antara Launch Center, Maranh?\u0153o, Brazil",
#     "Detail":"VLS-1 | SATEC, UNOSAT",
#     "Status Rocket":"StatusActive",
#     " Rocket":null,
#     "Status Mission":"Prelaunch Failure",
#     "Country of Launch":"Brazil",
#     "Companys Country of Origin":"Brazil",
#     "Private or State Run":"S",
#     "DateTime":"2003-08-25 00:00:00+00:00",
#     "Year":2003,
#     "Month":8,
#     "Day":25,
#     "Date":"25\/08\/2003",
#     "Time":"0:00"
#   },
#   "1":{
#     "Company Name":"AEB",
#     "Location":"VLS Pad, Alc?\u203antara Launch Center, Maranh?\u0153o, Brazil",
#     "Detail":"VLS-1 | SACI-2",
#     "Status Rocket":"StatusActive",
#     " Rocket":null,
#     "Status Mission":"Failure",
#     "Country of Launch":"Brazil",
#     "Companys Country of Origin":"Brazil",
#     "Private or State Run":"S",
#     "DateTime":"1999-12-11 19:40:00+00:00",
#     "Year":1999,
#     "Month":12,
#     "Day":11,
# ...
